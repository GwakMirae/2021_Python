# %% [markdown]
# # 시각화 패키지 맷플롯리브

# %% [markdown]
# Pyplot 서브 패키지 : 간단한 시각화

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %% [markdown]
# 라인플롯

# %%
plt.title("plot")
plt.plot([1,4,9,16])
plt.show()

# %%
plt.title("x ticks")
plt.plot([10,20,30,40],[1,4,9,16]) # x축 지정
plt.show()

# %% [markdown]
# 한글폰트 적용

# %%
# 맷플롯리브에서 한글 사용시 폰트 적용 필요

# %%
import matplotlib.font_manager

matplotlib.font_manager._rebuild()
sorted([f.name for f in matplotlib.font_manager.fontManager.ttflist if f.name.startswith("Nanum")])
# Out:
# ['NanumSquareRound',
#  'NanumSquareRound',
#  'NanumSquareRound',
#  'NanumSquareRound']

# %%
# 폰트 설정
mpl.rc('font', family='NanumSquareRound')
# 유니코드에서  음수 부호설정
mpl.rc('axes', unicode_minus=False)

# %%
plt.title('한글 제목')
plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.xlabel("엑스축 라벨")
plt.ylabel("와이축 라벨")
plt.show() #웨않되?
# Out:
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50641 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
import matplotlib.pyplot as plt
font1 = {'family': 'NanumSquareRound', 'size': 24, 
         'color':  'black'}
font2 = {'family': 'NanumSquareRound', 'size': 18, 'weight': 'bold',
         'color':  'darkred'}
font3 = {'family': 'NanumSquareRound', 'size': 12, 'weight': 'light',
         'color':  'blue'}

plt.plot([10, 20, 30, 40], [1, 4, 9, 16])
plt.title('한글 제목', fontdict=font1)
plt.xlabel('엑스 축', fontdict=font2)
plt.ylabel('와이 축', fontdict=font3)
plt.show()
# Out:
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 44544 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 47785 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\MIRAE\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 50641 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %% [markdown]
# 스타일

# %%
import matplotlib.pyplot as plt
plt.title("'rs--' style plot")
plt.plot([10,20,30,40],[1,4,9,16], 'rs--')
plt.show()

# %% [markdown]
# color

# %%
# 색이름 or 약자 or rgb코드

# %% [markdown]
# 마커

# %%
# 데이터의 위치를 나타내는 기호

# %% [markdown]
# 선스타일

# %%
# 실선(solid), 대시선(dashed), 점선(dotted), 대시-점선(dash-dit)
# -, --, -., :

# %% [markdown]
# 예제

# %%
plt.plot([10,20,30,40],[1,4,9,16], c="r",lw=5, ls="--", marker="o", ms=15, mec="c", mew=5, mfc="w")
plt.show()

# %% [markdown]
# 그림범위 지정

# %%
plt.plot([10,20,30,40],[1,4,9,16], c="r",lw=5, ls="--", marker="o", ms=15, mec="c", mew=5, mfc="w")
plt.xlim(0,50)
plt.ylim(-10,30)
plt.show()

# %% [markdown]
# 틱 설정

# %%
# 플롯이나 차트에서 축상의 위치표지 지점

# %%
import numpy as np
X = np.linspace(-np.pi, np.pi, 256)
C = np.cos(X)
plt.plot(X,C)
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi])
plt.yticks([-1,0,+1])
plt.grid()
plt.show()

# %% [markdown]
# 여러개의 선 그리기

# %%
t = np.arange(0.,5.,0.2)
plt.plot(t, t, 'r--', t, 0.5*t**2, 'bs:', t, 0.2*t**3, 'g^-')
plt.show()

# %% [markdown]
# 겹쳐그리기

# %%
plt.plot([1,4,9,16], 
         c="b", lw=5, ls="--", marker="o", ms=15, mec="g", mew=5, mfc="r")
plt.plot([9, 16, 4, 1],
         c="k", lw=3, ls=":", marker="s", ms=10, mec="m", mew=5, mfc="c")
plt.show()

# %% [markdown]
# 범례

# %%
# legend로 추가가능
# 위치 수동 설정 원하면 loc사용

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, ls="--", label="cosine")
plt.plot(X, S, ls=":", label="sine")
plt.legend(loc=2) # upper left
plt.show()

# %% [markdown]
# x, y축 라벨, 타이틀

# %%
X = np.linspace(-np.pi, np.pi, 256)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C, label="cosine")
plt.xlabel("time")
plt.ylabel("amplitude")
plt.title("Cosine Plot")
plt.show()

# %% [markdown]
# figure 객체

# %%
np.random.seed(0)
f1 = plt.figure(figsize=(10,2))
plt.plot(np.random.randn(100))
plt.show()

# %%
f1 = plt.figure(1)
plt.plot([1,2,3,4], 'ro:')

f2 = plt.gcf() # 현재 사용하고 있는 figure 객체 얻음
print(f1, id(f1))
print(f2, id(f2))
plt.show()
# Out:
# Figure(432x288) 2583765810568
# Figure(432x288) 2583765810568

# %% [markdown]
# axes 객체와 subplot 명령

# %%
# subplot(2,1,1) # 2row 1 col first
# subplot(2,1,2) # 2row 1col second

# %%
import numpy as np
x1 = np.linspace(0.0, 5.0)
x2 = np.linspace(0.0, 2.0)
y1 = np.cos(2*np.pi*x1) * np.exp(-x1)
y2 = np.cos(2*np.pi*x2)

ax1 = plt.subplot(2,1,1)
plt.plot(x1, y1, 'yo-')
plt.ylabel('Damped oscillation')

ax2 = plt.subplot(2,1,2)
plt.plot(x2, y2, 'r.-')
plt.xlabel('time(s)')
plt.ylabel('Undamped')

plt.tight_layout() # 플롯간 간격을 알아서 맞춰줌
plt.show()

# %%
np.random.seed(0)

plt.subplot(221) # 콤마 없이 표현 가능
plt.plot(np.random.rand(5))
plt.title("axes 1")

plt.subplot(222)
plt.plot(np.random.rand(5))
plt.title("axes 2")

plt.subplot(223)
plt.plot(np.random.rand(5))
plt.title("axes 3")

plt.subplot(224)
plt.plot(np.random.rand(5))
plt.title("axes 4")

plt.tight_layout()
plt.show()

# %%
fig, axes = plt.subplots(2, 2)

np.random.seed(0)
axes[0, 0].plot(np.random.rand(5))
axes[0, 0].set_title("axes 1")
axes[0, 1].plot(np.random.rand(5))
axes[0, 1].set_title("axes 2")
axes[1, 0].plot(np.random.rand(5))
axes[1, 0].set_title("axes 3")
axes[1, 1].plot(np.random.rand(5))
axes[1, 1].set_title("axes 4")

plt.tight_layout()
plt.show()

# %% [markdown]
# Axis 객체와 축

# %%
# twinx : x축을 공류하는 Axes 객체를 만듦

# %%
fig, ax0 = plt.subplots()
ax1 = ax0.twinx()
ax0.plot([10, 5, 2, 9, 7], 'r-', label="y0")
ax0.set_ylabel("y0")
ax0.grid(False)
ax1.plot([100, 200, 220, 180, 120], 'g:', label="y1")
ax1.set_ylabel("y1")
ax1.grid(False)
ax0.set_xlabel("x")
plt.show()
